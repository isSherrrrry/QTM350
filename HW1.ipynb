# %% [markdown]
# # Group 2 Homework 1 Solution Notebook

# %% [markdown]
# ## **Group Member Introduction**
# This is **Group 2** homework 1. In the team, we have Yulin Hu, Yijun Liu, Christopher Li, Ben Schwartz, and Wendy Sun. We will introduce ourselves below. Please feel free to check out our LinkedIn pages!

# %% [markdown]
# ### Yulin Hu
# ![4bd4b06fd1673a8f4cf079c553a4722.jpg](data:image/jpeg;base64,...)
# - Major: CS
# - [LinkedIn](https://www.linkedin.com/in/yulin-hu-9855ab1b2/)

# %% [markdown]
# ### Yijun Liu
# ![IMG_0441.JPG](data:image/jpeg;base64,...)
# - Major: CS & QSS Sociology
# - [LinkedIn](https://www.linkedin.com/in/yijunliu23/)
# - [Personal Website](www.liuyijun.com)

# %% [markdown]
# ###Christopher Li
# ![download.jpeg](data:image/jpeg;base64,...)
# - Major: QSS Psychology

# %% [markdown]
# ### Ben Schwartz
#
# ![IMG_6828 copy.jpg](data:image/jpeg;base64,...)
#
# *   Major: QSS Economics
# *   [Linkedin](https://www.linkedin.com/in/bschwartz26/)

# %% [markdown]
# ###Wendy Sun
# ![IMG_6595.jpeg](data:image/jpeg;base64,...)
# - Major: BBA + QSS
# - [LinkedIn](https://www.linkedin.com/in/sunwendy)

# %% [markdown]
# ## Import Neccessary Packages

# %%
import pandas as pd
import numpy as np
from sympy import symbols, solve
from sympy.sets.sets import false

# %% [markdown]
# ## Question 2
# Find a Linux command (google it) and use it to:
# * determine how much memory is available to you in this colab notebook
# * which version of linux this colab notebook is running on
# * given what you just found, search for how to update the system and update it.
#
# Next, use linux to create a text file (hint use `touch`).
#
# Then use redirection (recall there are `>` or `|`) to write into the text file how much memory. Specifically, redirect the output of the first command to the file you created. Do the same for the information you found about the linux version.
#
# How many lines are in your text file now? Use a linux command to find out.
#
# Cut the first field (a.k.a. column) from your text file using the `cut` command. What does it say? Use a linux command to display it.

# %% [markdown]
# ## Answer to Q2

# %%
# Determine free memory in the colab notebook
# !free -h 
# Find out the version of linux
# !uname -a
# update system
# !sudo apt-get update && sudo apt-get upgrade
# create a text file log.txt
# !touch log.txt
# write free memory into log
# !free -h > log.txt
# write linux version into log
# !uname -a >> log.txt
# find out the number of lines in log.txt
# !cat -n log.txt
# cut the first field and display it
# !cut -f 1 -d ' ' log.txt
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:           12Gi       819Mi       8.1Gi       1.0Mi       3.8Gi        11Gi
# Swap:            0B          0B          0B
# Linux bc9cbe16eeba 5.10.147+ #1 SMP Sat Dec 10 16:00:40 UTC 2022 x86_64 x86_64 x86_64 GNU/Linux
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:5 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# ...

# %% [markdown]
# ## Question 3
# Recall in notebook 1, an exercise posed the following question.
# > "Harvard's tuition in 1970 was \$4,070 (not including room, board, and fees).
# In 2019 it is \$46,340.  What was the annual rate of increase over that period, treating it as if it had compounded continuously?
#
#
# Did Harvard's tuition have an higher annual rate of increase than other school's? In this question, your group needs to gather data on *five* other schools, compute the annual increase for them, and compare with Harvard's. Intermix with your code an interesting narrative that explains why you are interested in those five schools, what you expected to see in their rate of increase, and what is actually seen after making the calculations. Include links to any data sources you use, and pictures as well as other markdown features to make your response visually appealing.

# %% [markdown]
# ## Answer to Q3

# %% [markdown]
# In Question 3, the question states that Harvard's tuition increases from 4,070 dollars in 1970 to 46,340 dollars in 2019. We try to determine whether Harvard's tuition have an higher annual rate of increase than other school's. In this question, we use the following formula to solve the annual compounded rate:
#
# $$\frac{\log(V/P)}{t}= r$$

# %% [markdown]
# For question 3, we decided to choose the following five schools because they are also **ivy league schools** as Harvard:
#
#
# 1. Princeton University
# 2. Columbia University
# 3. Yale University
# 4. Brown University
# 5. Cornell University
#
# ![ivy.jpeg](data:image/jpeg;base64,...)
#
# <figcaption align = "center"><i>Photo from <a href = "https://baystbull.com/heres-how-you-can-get-a-free-ivy-league-education-while-you-socially-distance/" target="_blank">Bay Street Bull</a></i></figcaption>
#
# We are expecting to see similar rate of increases in the tuition for those schools as well. They are also private and prestigious colleges in the United States. Particularly, we are expecting to see higher rate of increases for **Dartmouth University** due to its location in rural area. We predit that Dartmouth has higher maintainance costs due to the inconvenient tranportation, and potentially higher salaries to attract faculty.

# %% [markdown]
# ### Princeton University
# The tuition for Princeton University is \$2,500 (not including room, board, and fees) in [1970](https://www.nytimes.com/1970/01/05/archives/princeton-posts-higher-charges-annual-rises-seen.html
# ); and the tuition raises \$51,870 to in [2019](https://www.cnbc.com/2019/05/03/it-costs-73450-to-go-to-princetonheres-how-much-students-pay.html#:~:text=According%20to%20the%20Princeton%20undergraduate,a%20%24930%20residential%20college%20fee.).
#
# ### Columbia University
# The tuition for Columbia University is \$2,560 (not including room, board, and fees) in [1970](https://www.nytimes.com/1970/01/05/archives/princeton-posts-higher-charges-annual-rises-seen.html
# ); and the tuition raises to \$23,498 in [2019](https://www.ccis.edu/tuition-financial-aid/bachelors-and-associate/traditional-prior-years).
#
# ### Yale University
# The tuition for Yale University is $2,550 (not including room, board, and fees) in [1970](https://www.nytimes.com/1970/01/05/archives/princeton-posts-higher-charges-annual-rises-seen.html
# ); and the tuition raises to \$55,500 in [2019](https://www.cnbc.com/2019/04/18/it-costs-75925-to-go-to-yaleheres-how-much-students-actually-pay.html).
#
# ### Dartmouth University
# The tuition for Dartmouth University is $2,550 (not including room and board) in [1970](https://archive.dartmouthalumnimagazine.com/article/1970/2/1/the-college); and the tuition raises to \$55,605 in [2019](https://www.cnbc.com/2019/05/17/it-costs-76623-to-go-to-dartmouth--heres-how-much-students-pay.html#:~:text=The%20total%20cost%20to%20attend,plan%20(%243%2C248)%20or%20travel.).
#
# ### Cornell University
# The tuition for Cornell University is $2,600 (not including room and board) in [1970](https://www.nytimes.com/1970/01/25/archives/cornell-tuition-and-fees-to-increase-275-a-year.html); and the tuition raises to \$56,550 in [2019](https://cnycentral.com/news/local/cornell-tuition-decreasing-slightly-as-2019-2020-budget-passes).

# %%
P = np.array([4070, 2500 , 2560, 2550, 2550, 2600]) #In order, we create a list that contain the tuitions of Harvard and the 5 ivy league schools in year 1970
V = np.array([46340, 51870, 23498, 55500, 55605, 56550]) #V contains the tuitions of Harvard and the 5 ivy league schools in year 2019
t = 2019-1970 # calculate the difference

# %%
r = np.log(V/P)/t # We use the formula to calculate r
percentages = r * 100 # from decimal to percentage 
percentages = percentages.tolist() #change the type to a list

# %%
college_names = ["Harvard", "Princeton", "Columbia", "Yale", "Dartmouth", "Cornell"] #a list of college names
data = {"college": college_names, "rate": percentages} #put the data into a dictionary for creating a table
df = pd.DataFrame(data, index=["1","2","3","4","5","6"]) #create a table to see the results easier
df["rank"] = df["rate"].rank(method='min') # add a column that shows their ranking; the college with lowest rate will rank the first
df # print the dataframe
# Out:
#      college      rate  rank
# 1    Harvard  4.964005   2.0
# 2  Princeton  6.188673   3.0
# 3   Columbia  4.524302   1.0
# 4       Yale  6.286305   5.0
# 5  Dartmouth  6.290163   6.0
# 6    Cornell  6.284926   4.0

# %% [markdown]
# From the table, we can clearly see that Harvard has a low increase rate (ranks at the 2rd position) among other ivy leauge schools. Columbia has the lowest compounded rate of increase, while Dartmouth has the highest. Because of the location, we predited that Dartmouth might have a high rate, which is completely true. In addition, the table above provides an general overview of the tuition increases that ivy league schools are experiencing.

# %% [markdown]
# ## Answer to Question 4
#
# Use the examples provided in the textbook to use Python to calculate:
# * The current date and time
# * The number of days since you were born (for each group member).
# * What day were you born on? (was it a Monday, Tuesday,...)
# * What day will it be when you turn 40? (will it be a Monday, Tuesday,...)
# * What date (which day in which month in which year) will it be when you turn 10000 days old?

# %%
# Find the current date and time using Timestamp.now
current_time = pd.Timestamp.now()
print("Current date and time:", current_time)
# Out:
# Current date and time: 2023-02-03 03:50:48.317508

# %%
# Birthday for Yulin Hu
print("Birthday for Yulin Hu")
year = 2000 # input the year
month = 9 # input the month 
day = 19 #input the date 
birthdate = pd.Timestamp(year, month, day) # convert to timestamp
today = pd.Timestamp.now() # today
days_since_birth = (today - birthdate).days # count number of days since born
print("Number of days since birth:", days_since_birth) # print

# What day were you born on? (was it a Monday, Tuesday,...)
day_of_week = birthdate.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Yulin were born on a", days[day_of_week])

# What day will it be when you turn 40? (will it be a Monday, Tuesday,...)
forty_year_later = birthdate + pd.DateOffset(years=40)
day_of_week = forty_year_later.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Yulin will turn 40 on a", days[day_of_week])

# What date (which day in which month in which year) will it be when you turn 10000 days old?
ten_thousand_days_later = birthdate + pd.DateOffset(days=10000)
print("Yulin will turn 10000 days old on", ten_thousand_days_later)
# Out:
# Birthday for Yulin Hu
# Number of days since birth: 8172
# Yulin were born on a Tuesday
# Yulin will turn 40 on a Wednesday
# Yulin will turn 10000 days old on 2028-02-05 00:00:00

# %%
# Birthday for Wendy Sun
print("Birthday for Wendy Sun")
year = 2001 # input the year
month = 10 # input the month 
day = 12 #input the date 
birthdate = pd.Timestamp(year, month, day) # convert to timestamp
today = pd.Timestamp.now() # today
days_since_birth = (today - birthdate).days # count number of days since born
print("Number of days since birth:", days_since_birth) # print

# What day were you born on? (was it a Monday, Tuesday,...)
day_of_week = birthdate.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Wendy were born on a", days[day_of_week])

# What day will it be when you turn 40? (will it be a Monday, Tuesday,...)
forty_year_later = birthdate + pd.DateOffset(years=40)
day_of_week = forty_year_later.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Wendy will turn 40 on a", days[day_of_week])

# What date (which day in which month in which year) will it be when you turn 10000 days old?
ten_thousand_days_later = birthdate + pd.DateOffset(days=10000)
print("Wendy will turn 10000 days old on", ten_thousand_days_later)
# Out:
# Birthday for Wendy Sun
# Number of days since birth: 7784
# Wendy were born on a Friday
# Wendy will turn 40 on a Saturday
# Wendy will turn 10000 days old on 2029-02-27 00:00:00

# %%
# Birthday for Ben Schwartz
print("Birthday for Ben Schwartz")
year = 2001 # input the year
month = 2 # input the month 
day = 6 #input the date 
birthdate = pd.Timestamp(year, month, day) # convert to timestamp
today = pd.Timestamp.now() # today
days_since_birth = (today - birthdate).days # count number of days since born
print("Number of days since birth:", days_since_birth) # print

# What day were you born on? (was it a Monday, Tuesday,...)
day_of_week = birthdate.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Ben was born on a", days[day_of_week])

# What day will it be when you turn 40? (will it be a Monday, Tuesday,...)
forty_year_later = birthdate + pd.DateOffset(years=40)
day_of_week = forty_year_later.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Ben will turn 40 on a", days[day_of_week])

# What date (which day in which month in which year) will it be when you turn 10000 days old?
ten_thousand_days_later = birthdate + pd.DateOffset(days=10000)
print("Ben will turn 10000 days old on", ten_thousand_days_later)
# Out:
# Birthday for Ben Schwartz
# Number of days since birth: 8032
# Ben was born on a Tuesday
# Ben will turn 40 on a Wednesday
# Ben will turn 10000 days old on 2028-06-24 00:00:00

# %%
# Birthday for Yijun Liu
print("Birthday for Yijun Liu")
year = 2001 # input the year
month = 5 # input the month 
day = 23 #input the date 
birthdate = pd.Timestamp(year, month, day) # convert to timestamp
today = pd.Timestamp.now() # today
days_since_birth = (today - birthdate).days # count number of days since born
print("Number of days since birth:", days_since_birth) # print

# What day were you born on? (was it a Monday, Tuesday,...)
day_of_week = birthdate.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Yijun were born on a", days[day_of_week])

# What day will it be when you turn 40? (will it be a Monday, Tuesday,...)
forty_year_later = birthdate + pd.DateOffset(years=40)
day_of_week = forty_year_later.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Yijun will turn 40 on a", days[day_of_week])

# What date (which day in which month in which year) will it be when you turn 10000 days old?
ten_thousand_days_later = birthdate + pd.DateOffset(days=10000)
print("Yijun will turn 10000 days old on", ten_thousand_days_later)
# Out:
# Birthday for Yijun Liu
# Number of days since birth: 7926
# Yijun were born on a Wednesday
# Yijun will turn 40 on a Thursday
# Yijun will turn 10000 days old on 2028-10-08 00:00:00

# %%
# Birthday for Chris Li
print("Birthday for Chris Li")
year = 2001 # input the year
month = 5 # input the month 
day = 23 #input the date 
birthdate = pd.Timestamp(year, month, day) # convert to timestamp
today = pd.Timestamp.now() # today
days_since_birth = (today - birthdate).days # count number of days since born
print("Number of days since birth:", days_since_birth) # print

# What day were you born on? (was it a Monday, Tuesday,...)
day_of_week = birthdate.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Chris were born on a", days[day_of_week])

# What day will it be when you turn 40? (will it be a Monday, Tuesday,...)
forty_year_later = birthdate + pd.DateOffset(years=40)
day_of_week = forty_year_later.dayofweek
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("Chris will turn 40 on a", days[day_of_week])

# What date (which day in which month in which year) will it be when you turn 10000 days old?
ten_thousand_days_later = birthdate + pd.DateOffset(days=10000)
print("Chris will turn 10000 days old on", ten_thousand_days_later)
# Out:
# Birthday for Chris Li
# Number of days since birth: 7926
# Chris were born on a Wednesday
# Chris will turn 40 on a Thursday
# Chris will turn 10000 days old on 2028-10-08 00:00:00

# %% [markdown]
# ## Question 5
# ### Buying a house
# Houses are expensive. Either many years of saved income or a loan are necessary to purchase a house.
#
# By making calculations based around a simple model, in this problem you will explore the influence that the interest rate on mortgages (i.e. home loans) has on home prices.
#
# #### Variables
#  We will denote the interest rate on mortgages with the python variable `rate`, the purchase price of the home with the variable `purchase_price`, the amount of yearly spending/saving that a buyer can afford with the variable `house_spend`, and the amount of property taxes with the `prop_tax=(0.01)*purchase price` (which is approximately correct for Georgia).

# %%
#@title Interest rate on 30 year mortgage (e.g. if 3%, enter 3)
percentage =  3#@param {type:"number"}
rate = percentage/100

# %% [markdown]
# #### Model
# The specifics of loans for home buying vary greatly from one country to the next. For simplicity, we will base this model around home buying in the United States. Similarly, we will assume that the income of the home buyer is the [median income in the US](https://fred.stlouisfed.org/series/MEHOINUSA672N), $63,179, and that the amount `house_spend` is the [maximum usually suggested](https://www.forbes.com/sites/forbesfinancecouncil/2020/04/10/determining-what-percent-of-your-income-you-can-afford-to-spend-on-your-home/#544cda8737b0), namely 1/4 of gross income. Hence the variable `house_spend` we will fix as follows.

# %%
house_spend=63179/4

# %% [markdown]
# ###Extreme Buyer Profiles
# Consider the following two extremes in the profiles of home buyers.
#
# #### Saver profile
# The *saver* insists on buying a house in cash, without a loan. Note, interest rates will impact the saver, as you should assume they put the money they are saving towards a house purchase into a safe liquid investment that earns interest. For example, 10 year US treasuries. For simplicity, you may assume that this interest rate is the same as the rate `r` on mortgages. In reality it is lower, but they are strongly correlated.
#
# #### Renter profile
# The *renter* profile insists on buying a house with as little cash as possible. For example, they may be attempting *interest rate arbitrage*, where one invests whatever cash they have in investments which they hope will have a higher rate of return over the liftime of the home loan than the interest rate `rate` on the home loan. Or, they simply may not have the cash to spend.
# Typically, to avoid additional fees, it is necessary to make a down payment of 20% of the purchase price of the home, while the minimum down payment allowed is 5%. The loan term is most often 30 years, meaning the amount borrowed is paid back in full over 30 years, although 15 and 10 are also used by some buyers to minimize the amount paid in interest. Since the renter profile is taking borrowing to the extremes, we will assume they use a 30 year loan term.
#
# For simplicity, we will assume in the calculations we make below that the renter profile puts 0% down towards the purchase price and borrows the purchase price at the interest rate `rate`.

# %% [markdown]
# ### Answer to Question 5

# %% [markdown]
# #### Task 1

# %% [markdown]
# **Question**: With rates at 3%, the renter profile can afford a house which costs $312,196. How many years would the saver profile have to save to afford that?

# %%
s = saver_house_price = 312,196 # set house price 
h = house_spend = 63179/4 # set house spend, as suggested to be 1/4 of gross income 
r = rate = 0.03 # interest rate
t = symbols('t') #a symbolic math expression using t can be created, plugging into the original function saver_house_price = house_spend*( ((1 + rate)**time - 1) / rate ) 
time = solve((63179/4) * (((1+0.03)**t - 1)/ 0.03) - 312196) # solve the function for saver house price mentioned above
f"The saver profile would have to save ${round(time[0],2)} years to afford it"
# Out:
# 'The saver profile would have to save $15.75 years to afford it'

# %% [markdown]
# **Question**: How many years will it take for the saver profile buyer to save enough to purchase the home that the renter profile can afford with interest rates at your chosen level?
#
# The current national average 30-year mortgage rate is 6.46% [Today’s 30-year mortgage rates](https://www.bankrate.com/mortgages/30-year-mortgage-rates/?mortgageType=Purchase&partnerId=br3&pid=br3&pointsChanged=false&purchaseDownPayment=126000&purchaseLoanTerms=30yr&purchasePoints=All&purchasePrice=630000&purchasePropertyType=SingleFamily&purchasePropertyUse=PrimaryResidence&searchChanged=false&showingStacked=all&ttcid&userCreditScore=740&userFha=false&userVeteranStatus=NoMilitaryService&zipCode=30033)

# %%
affordable_monthly_payment = (63179/4)/12 #(house_spend)/12, monthly payment 
rate = 0.0646 # interest rate
c=rate/12 # monthly interest rate
n = 12*30 # number of months in 30 years
renter_house_price = affordable_monthly_payment/( (c*(1 + c)**n)/((1 + c)**n - 1)) # solve the rental house payment via the formula
#We also round the answer to two decimal places to make it neat below
f"The renter profile can afford to buy a house with a purchase price of ${round(renter_house_price,2)} at the current nation average 30-year mortgage rate at 6.46%"
# Out:
# 'The renter profile can afford to buy a house with a purchase price of $209111.23 at the current nation average 30-year mortgage rate at 6.46%'

# %% [markdown]
# #### Task 2

# %% [markdown]
# **Question**: With rates at 5%, calculate what how many years the saver profile needs to save to be able to buy a house which is priced at the current median price for homes in Atlanta.

# %% [markdown]
# Atlanta typical home values according to Zillow is \$404,263
# [Atlanta Home Values](https://www.zillow.com/home-values/37211/atlanta-ga/)

# %%
rate = 0.05 # interest rate 
x = symbols('x') # set a variable for solving function 
expr = house_spend*( ((1 + rate)**x - 1) / rate ) - 404263 # write the expression of the function based on the formula provided for saver. We will solve for x 
sol = solve(expr) # solve for x 
#We also round the answer to two decimal places to make it neat below
f"It will take saver profile {round(sol[0],2)} years to buy a typical house in Atlanta with 5% interest rate at the current median price for homes in Atlanta ($404,263)"
# Out:
# 'It will take saver profile 16.89 years to buy a typical house in Atlanta with 5% interest rate at the current median price for homes in Atlanta ($404,263)'

# %% [markdown]
# #### Task 3

# %% [markdown]
# **Question**: With rates at 2.5%, calculate what how many years the saver profile needs to save to be able to buy a house which is priced at the current median price for homes in Atlanta.

# %%
rate = 0.025 # interest rate 
x = symbols('x') # set a variable for solving function 
expr = house_spend*( ((1 + rate)**x - 1) / rate ) - 404263  # write the expression of the function based on the formula provided for saver. We will solve for x, which is the number of years
sol = solve(expr) # solve for x 
#We also round the answer to two decimal places to make it neat below
f"It will take saver profile {round(sol[0],2)} years to buy a typical house in Atlanta with 5% interest rate at the current median price for homes in Atlanta ($404,263)"
# Out:
# 'It will take saver profile 20.03 years to buy a typical house in Atlanta with 5% interest rate at the current median price for homes in Atlanta ($404,263)'

# %% [markdown]
# **Question**: With rates at 16%, calculate what how many years the saver profile needs to save to be able to buy a house which is priced at the current median price for homes in Atlanta.

# %%
rate = 0.16  # interest rate 
x = symbols('x') # set a variable for solving function 
expr = house_spend*( ((1 + rate)**x - 1) / rate ) - 404263  # write the expression of the function based on the formula provided for saver. We will solve for x, which is the number of years
sol = solve(expr) # solve for x 
#We also round the answer to two decimal places to make it neat below
f"It will take saver profile {round(sol[0],2)} years to buy a typical house in Atlanta with 5% interest rate at the current median price for homes in Atlanta ($404,263)"
# Out:
# 'It will take saver profile 10.97 years to buy a typical house in Atlanta with 5% interest rate at the current median price for homes in Atlanta ($404,263)'

# %% [markdown]
# #### Task 4

# %% [markdown]
# **Question**: Suppose that a house is currently on the market with an asking price of \$725,000 at current interest rates on a 30-year loan. Calculate how large `house_spend` would need to be for the renter profile buyer to be able to purchase this house.
#
#
# At Atlanta (30002), the current interest rate of a house price of \$725,000 is [5.25%](https://www.bankrate.com/mortgages/30-year-mortgage-rates/?mortgageType=Purchase&partnerId=br3&pid=br3&pointsChanged=false&purchaseDownPayment=145000&purchaseLoanTerms=30yr&purchasePoints=All&purchasePrice=725000&purchasePropertyType=SingleFamily&purchasePropertyUse=PrimaryResidence&searchChanged=false&showingStacked=all&ttcid&userCreditScore=740&userFha=false&userVeteranStatus=NoMilitaryService&zipCode=30002) .

# %%
rate = 0.0525 # interest rate 
x = symbols('x') # set a variable for solving function 
c = rate / 12 # monthly interest rate
n = 12*30 # number of months in 30 years
expr = x/((c*(1 + c)**n)/((1 + c)**n - 1))-725000  # write the expression of the function based on the formula provided for renter. We will solve for x, which is the house spend.
sol = solve(expr) # solve for x 
ans = round(sol[0]*12,2) # we found the monthly number so we need to multiply it by 12. We also round the answer to two decimal places to make it neat 
f"The house_spend needs to be ${ans} for the renter profile buyer to be able to purchase this house of $725,000 at the current interest rate at 5.25%"
# Out:
# 'The house_spend needs to be $48041.72 for the renter profile buyer to be able to purchase this house of $725,000 at the current interest rate at 5.25%'

# %% [markdown]
# #### Task 5

# %% [markdown]
# **Question**: Suppose interest rates suddenly climb a percentage point from the one you used in task 4. Redo the previous calculation to see what house_spend needs to be under this new interest rate.

# %%
rate = 0.0625 # interest rate 
x = symbols('x') # set a variable for solving function 
c = rate / 12 # monthly interest rate
n = 12*30 # number of months in 30 years
expr = x/((c*(1 + c)**n)/((1 + c)**n - 1))-725000 # write the expression of the function based on the formula provided for renter. We will solve for x, which is the house_spend
sol = solve(expr) # solve for x 
ans = round(sol[0]*12,2) # we found the monthly number so we need to multiply it by 12. We also round the answer to two decimal places to make it neat 
f"The house_spend needs to be ${ans} for the renter profile buyer to be able to purchase this house of $725,000 at the current interest rate at 5.25%"
# Out:
# 'The house_spend needs to be $53567.40 for the renter profile buyer to be able to purchase this house of $725,000 at the current interest rate at 5.25%'

# %% [markdown]
# #### Task 6

# %% [markdown]
# **Question**: Suppose that suddenly interest rates drop a percentage point from the one you used in task 4. What can the renter afford to pay now? Should the home sellers raise the asking price from $725,000 to a higher number?

# %%
rate = 0.0425 # interest rate 
x = symbols('x') # set a variable for solving function 
c = rate / 12 # monthly interest rate
n = 12*30 # number of months in 30 years
expr = (48041.72/12) /((c*(1 + c)**n)/((1 + c)**n - 1)) - x # write the expression of the function based on the formula provided for renter. We will solve for x, which is the house price
sol = solve(expr) # solve the above expression

expr2 = x /((c*(1 + c)**n)/((1 + c)**n - 1)) - 725000 # write the expression of the function based on the formula provided for renter. We will solve for x, which is the house_spend
sol2 = solve(expr2) # solve the above expression
ans2 = round(sol2[0]*12,2) # we found the monthly number so we need to multiply it by 12. We also round the answer to two decimal places to make it neat 
f"For a house price at $725,000 and with a percetage point lower interest rate, the house_spend now only needs to be at ${ans2} to afford the house. If we have the same house_spend from task 4 and a percentage point lower interest rate, the renter now is able to afford to pay a house at price ${ans}. Thus, the home sellers should raise the price from $725000 to ${ans}."
# Out:
# 'For a house price at $725,000 and with a percetage point lower interest rate, the house_spend now only needs to be at $42798.77 to afford the house. If we have the same house_spend from task 4 and a percentage point lower interest rate, the renter now is able to afford to pay a house at price $53567.40. Thus, the home sellers should raise the price from $725000 to $53567.40.'

# %% [markdown]
# #### Bonus question
# When, historically, were the least years required for the saver profile, with a median income for the time, to buy a median priced home? When, historically, was the renter profile able to purchase the most expensive home, assuming the monthly house spend they are making is based on median income for the time as we did in our model.

# %%
# function used to find the years required for the saver profile with a median income for the time, to buy a median priced home
def findYear(income, rate, house_price):
  house_spend = income / 4 # set house spend, as suggested to be 1/4 of gross income 
  x = symbols('x') #a symbolic math expression using t can be created, plugging into the original function saver_house_price = house_spend*( ((1 + rate)**time - 1) / rate ) 
  expr = house_spend*( ((1 + rate)**x - 1) / rate ) - house_price # solve the function for saver house price mentioned above
  sol = solve(expr)
  return sol # return the year

# %%
# function used to find price that renter profile is able to purchase on a 30-year loan, assuming the monthly house spend they are making is based on median income
def findPrice(income, rate):
  c = rate / 12 # monthly interest rate
  x = symbols('x') # set a variable for solving function 
  n = 12 * 30 # number of months in 30 years
  expr = (income/12) /((c*(1 + c)**n)/((1 + c)**n - 1)) - x # write the expression of the function based on the formula provided for renter. We will solve for x, which is the house price
  sol = solve(expr) # solve the above expression
  return sol # return the house price

# %%
from google.colab import files
uploaded = files.upload() # upload the files
# Out:
#      <input type="file" id="files-b3dbfabc-f1cb-4bb3-9038-14a56f9f2649" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3dbfabc-f1cb-4bb3-9038-14a56f9f2649">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load the datasets. Dataset is now stored in a Pandas Dataframe
median_income = pd.read_csv("m_income_3.csv") #read median_income dataset 
median_house_price = pd.read_csv("house_price_2.csv") #read median_house_price dataset
interest_rate = pd.read_csv("rate.csv") #read interest rate dataset

# %%
# merge the three datasets into one dataset 
all_df = median_income.merge(median_house_price, on='year', how='left') # merge median_income and median_house_price
all_df = all_df.merge(interest_rate, on='year', how='left') #merge interest_rate to the other two
all_df #print the dataframe
# Out:
#     year  income   house_price      rate
# 0   1990   30636   97544.59667  8.096521
# 1   1991   31241   97208.43583  5.685014
# 2   1992   32264   99644.09167  3.521066
# 3   1993   34076  102058.92580  3.021342
# 4   1994   35492  105474.13080  4.206329
# 5   1995   37005  108201.33000  5.834301
# 6   1996   38885  111397.07920  5.300464
# 7   1997   40696  114577.61080  5.461507
# 8   1998   41990  120121.71580  5.350932
# 9   1999   42228  127460.72330  4.972356
# 10  2000   42409  136007.55080  6.237432
# 11  2001   43318  145429.00330  3.878356
# 12  2002   44334  155691.44250  1.666795
# 13  2003   46326  167617.43250  1.126493
# 14  2004   48201  183405.55420  1.350328
# 15  2005   50233  202519.97750  3.217068
# 16  2006   50303  214346.64920  4.965425
# 17  2007   49777  214208.88830  5.017315
# 18  2008   49276  196821.29250  1.924180
# 19  2009   50054  185330.21080  0.158603
# 20  2010   51017  180109.68670  0.176247
# 21  2011   51939  172573.64420  0.101507
# ...

# %%
# looping through each row to find the house_price 
all_df['income'] = all_df['income'].astype('float') # change the colume data type to float 
all_df['rate'] = all_df['rate'].astype('float') # change the colume data type to float 
all_df['house_price'] = all_df['house_price'].astype('float') # change the colume data type to float 
all_df['new_year'] = all_df['year']  # assign random value (year) to the new colume that record the number of years save need to save
all_df['house_all'] = all_df['year'] # assign random value (year) to the new colume that record the house price renter can pay

for index in all_df.index: #loop all rows 
  all_df['new_year'][index] = findYear(all_df['income'][index], all_df['rate'][index], all_df['house_price'][index]) #use findYear to find how many years for the saver to buy te house
  all_df['house_all'][index] = findPrice(all_df['income'][index], all_df['rate'][index]) # use findPrice to find the price they can afford
# Out:
# <ipython-input-111-295c13bc98ac>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['new_year'][index] = findYear(all_df['income'][index], all_df['rate'][index], all_df['house_price'][index]) #use findYear to find how many years for the saver to buy te house
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-111-295c13bc98ac>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
all_df["rank_year"] = all_df["new_year"].rank(method='min') # add a column that shows their ranking; the lowest year will rank first
all_df["rank_house"] = all_df["house_all"].rank(method='max') # add a column that shows their ranking; the highest price will rank first
all_df
# Out:
#     year   income   house_price      rate            new_year  \
# 0   1990  30636.0   97544.59667  8.096521  [2.10404934105363]
# 1   1991  31241.0   97208.43583  5.685014  [2.24925488419211]
# 2   1992  32264.0   99644.09167  3.521066  [2.51562277072122]
# 3   1993  34076.0  102058.92580  3.021342  [2.59856575817388]
# 4   1994  35492.0  105474.13080  4.206329  [2.38311710857904]
# 5   1995  37005.0  108201.33000  5.834301  [2.20480686806641]
# 6   1996  38885.0  111397.07920  5.300464  [2.23995378280712]
# 7   1997  40696.0  114577.61080  5.461507  [2.21627762120533]
# 8   1998  41990.0  120121.71580  5.350932  [2.23457514539756]
# 9   1999  42228.0  127460.72330  4.972356  [2.30056370519842]
# 10  2000  42409.0  136007.55080  6.237432  [2.22033420281288]
# 11  2001  43318.0  145429.00330  3.878356  [2.50619829831889]
# 12  2002  44334.0  155691.44250  1.666795  [3.25743537240766]
# 13  2003  46326.0  167617.43250  1.126493  [3.77867559950769]
# ...

# %% [markdown]
# We downloaded the federal reserve interest rate dataset from Kaggle for this assignment. Since 1954, it includes monthly data on the economic conditions in the United States. (https://www.kaggle.com/datasets/federalreserve/interest-rates). The second dataset that we utilized was obtained from DQYDJ. It provides historical monthly median values for single-family homes in the United States from January 1953 to the present, along with graphs. (https://dqydj.com/historical-home-prices/). In addition, we implement a dataset of the United States' median household income from 1990 to 2020.(https://www.statista.com/statistics/200838/median-household-income-in-the-united-states/).  The median household income represents the income of households, which includes the householder's income and the income of all individuals aged 15 or older living in the household.
#
# We found that 1990 is the best year for both saver's profile and renter's profile, as shown in ranking the 1st in both rank_year and rank_house.
